# %%
#!connect jupyter --kernel-name python3 --kernel-spec python3
# Out:
# The `#!connect jupyter` feature is in preview. Please report any feedback or issues at https://github.com/dotnet/interactive/issues/new/choose.
# Kernel added: #!python3

# %% [markdown]
# # Python

# %%
from random import uniform

def estimate_pi(samples: int) -> float:  
    ''' Estimate the value of pi using a Monte Carlo simulation. '''  
    
    def get_samples(n: int) -> list:
        '''Get a set of random sample within the range 0-1.'''
        return [uniform(0,1) for sample in range(n)]
    
    # Get a uniform distribution of coordinates.
    x, y = get_samples(samples), get_samples(samples)

    # Count the number of coordinates inside the quadrant via the Pythagorean Theorem.
    inside = sum(1 for x, y in zip(x, y) if x**2 + y**2 <= 1) 

    # Get the proportion of samples inside the quadrant.
    # Multiply the result by 4.
    estimate = (inside/samples)*4

    # Return the estimate of pi.
    return estimate

estimate_pi(1000000)
# Out:
# 3.141332

# %% [markdown]
# # JavaScript

# %%
function estimate_pi(samples){
    // Estimate the value of pi using a Monte Carlo simulation. 

    function get_samples(n){
        //Get a set of random sample within the range 0-1.
        let a = []
        for (i = 0; i <= n; i++){a[i] = Math.random()}
        return a
    }

    // Get a uniform distribution of coordinates.
    let x = get_samples(samples); let y = get_samples(samples)

    // Count the number of coordinates inside the quadrant via the Pythagorean Theorem.
    inside = 0
    for (i = 0; i <= x.length - 1; i++){
        if (x[i]**2 + y[i]**2 <= 1){inside += 1}
    }

    // Get the proportion of samples inside the quadrant.
    // Multiply the result by 4.
    estimate = (inside/samples)*4

    // Return the estimate of pi.
    return estimate
}

console.log(estimate_pi(1000000))
# Out:
# 3.143936

# %% [markdown]
# # C#

# %% [markdown]
# # PowerShell

# %% [markdown]
# # HTML
